# %%
import pydst
import pandas as pd

# %%
Dst = pydst.Dst(lang='en')

# %%
tables = Dst.get_tables(subjects=['02'])

# %%
folk_vars = Dst.get_variables(table_id='FOLK1C')

# %%
folk_vars
# Out:
#          id               text  elimination   time                      map  \
# 0    OMRÅDE             region         True  False  denmark_municipality_07
# 1       KØN                sex         True  False                      NaN
# 2     ALDER                age         True  False                      NaN
# 3  HERKOMST           ancestry         True  False                      NaN
# 4    IELAND  country of origin         True  False               Verden_dk2
# 5       Tid               time        False   True                      NaN
#
#                                               values
# 0  [{'id': '000', 'text': 'All Denmark'}, {'id': ...
# 1  [{'id': 'TOT', 'text': 'Total'}, {'id': '1', '...
# 2  [{'id': 'IALT', 'text': 'Total'}, {'id': '0-4'...
# 3  [{'id': 'TOT', 'text': 'Total'}, {'id': '5', '...
# 4  [{'id': '0000', 'text': 'Total'}, {'id': '5100...
# 5  [{'id': '2008K1', 'text': '2008Q1'}, {'id': '2...

# %%
for id in ['OMRÅDE','HERKOMST','IELAND']:
    print(id)
    values = folk_vars.loc[folk_vars.id == id,['values']].values[0,0]
    for value in values:      
        print(f' id = {value["id"]}, text = {value["text"]}')
# Out:
# OMRÅDE
#  id = 000, text = All Denmark
#  id = 084, text = Region Hovedstaden
#  id = 101, text = Copenhagen
#  id = 147, text = Frederiksberg
#  id = 155, text = Dragør
#  id = 185, text = Tårnby
#  id = 165, text = Albertslund
#  id = 151, text = Ballerup
#  id = 153, text = Brøndby
#  id = 157, text = Gentofte
#  id = 159, text = Gladsaxe
#  id = 161, text = Glostrup
#  id = 163, text = Herlev
#  id = 167, text = Hvidovre
#  id = 169, text = Høje-Taastrup
#  id = 183, text = Ishøj
#  id = 173, text = Lyngby-Taarbæk
#  id = 175, text = Rødovre
#  id = 187, text = Vallensbæk
#  id = 201, text = Allerød
#  id = 240, text = Egedal
#  id = 210, text = Fredensborg
#  id = 250, text = Frederikssund
#  id = 190, text = Furesø
#  id = 270, text = Gribskov
#  id = 260, text = Halsnæs
#  id = 217, text = Helsingør
#  id = 219, text = Hillerød
#  id = 223, text = Hørsholm
#  id = 230, text = Rudersdal
#  id = 400, text = Bornholm
#  id = 411, text = Christiansø
# ...

# %%
variables = {'OMRÅDE':['*'],'HERKOMST':["*"],"IELAND":["*"],"TID":["*"]}
folk_api = Dst.get_data(table_id = 'FOLK1C', variables=variables)

# %%
folk_q1 = folk_api[folk_api["TID"].str.contains("Q1")]

# %%
folk_q1["TID"]=pd.to_datetime(folk_q1["TID"])
folk_q1["YEAR"] = folk_q1["TID"].dt.year
folk_q1 = folk_q1.drop(["TID"],axis=1)
# Out:
# /Users/smeden/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/smeden/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
folk_q1.head()
# Out:
#        OMRÅDE    HERKOMST      IELAND    KØN  ALDER  INDHOLD  YEAR
# 32959  Herlev  Immigrants      Brazil  Total  Total        7  2011
# 32960  Herlev  Immigrants      Canada  Total  Total       12  2011
# 32961  Herlev  Immigrants       Chile  Total  Total        5  2011
# 32962  Herlev  Immigrants    Colombia  Total  Total        3  2011
# 32963  Herlev  Immigrants  Costa Rica  Total  Total        1  2011
